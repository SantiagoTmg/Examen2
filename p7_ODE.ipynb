# %%
# %load_ext autoreload

# %% [markdown]
# # ODE

# %% [markdown]
# ## Ejercicio 1
# $y'= -5y+5t^2+2t$
# * $0 \le t \le 1$
# * $y(t_0)=1/3$
# * $N=10$

# %%
# %autoreload 2
from src import ODE_euler
# Out:
# [08-07 13:19:47][INFO] 2025-08-07 13:19:47.000375
# [08-07 13:19:47][INFO] santi| 2025-08-07 13:19:47.100699
# [08-07 13:19:47][INFO] 2025-08-07 13:19:47.103697
# [08-07 13:19:47][INFO] santi| 2025-08-07 13:19:47.105695

# %% [markdown]
# ## Comparación con la solución real
# La solución real de la ecuación diferencial es:
# $y(t)=t^2 +1/3e^{-5t}$
#
# * Grafique la solución real y la aproximación obtenida con el método de Euler en una misma gráfica.

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(t, y):
    return -5*y + 5*t**2 + 2*t

def f_real(t):
    return t**2 + 1/3 * np.exp(-5 * t)

a, b = 0, 1
y_t0=1/3
N=10
y_valores, t_valores, h = ODE_euler(a=a, b=b, f=f, y_t0=y_t0, N=N)

t_real = np.linspace(a, b, 400)
y_real = f_real(t_real)

plt.plot(t_valores, y_valores, label='Euler con un N de 10', marker='o', color = 'red')
plt.plot(t_real, y_real, label=' Solucion', linestyle='--', color = 'black')
plt.xlabel('t')
plt.ylabel('y(t)')
plt.title('Euler con un N de 10')
plt.legend()
plt.grid()
plt.show()

# %%
print (f"Valor de h: {h}")
# Out:
# Valor de h: 0.1

# %% [markdown]
# # Errores
# Calcule el eeror relativo para diferentes valores de N.

# %%
# Calcular error relativo
a, b = 0, 1
y_t0=1/3
N=10
y_valores, t_valores, h = ODE_euler(a=a, b=b, f=f, y_t0=y_t0, N=N)

y_exacto = np.interp(t_valores, t_real, y_real)

error = np.abs((y_valores - y_exacto) / y_exacto)

error_promedio = np.mean(error)

print(f'Error promedio: {error_promedio:.6f}')
# Out:
# Error promedio: 0.129100

# %%
# Calcular error relativo
a, b = 0, 1
y_t0=1/3
N=5
y_valores, t_valores, h = ODE_euler(a=a, b=b, f=f, y_t0=y_t0, N=N)

y_exacto = np.interp(t_valores, t_real, y_real)

error = np.abs((y_valores - y_exacto) / y_exacto)

error_promedio = np.mean(error)

print(f'Error promedio: {error_promedio:.6f}')
# Out:
# Error promedio: 0.279793

# %%
# Calcular error relativo
a, b = 0, 1
y_t0=1/3
N=20
y_valores, t_valores, h = ODE_euler(a=a, b=b, f=f, y_t0=y_t0, N=N)

y_exacto = np.interp(t_valores, t_real, y_real)

error = np.abs((y_valores - y_exacto) / y_exacto)

error_promedio = np.mean(error)

print(f'Error promedio: {error_promedio:.6f}')
# Out:
# Error promedio: 0.063152
