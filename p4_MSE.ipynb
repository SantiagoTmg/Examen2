.211, 26.017), (-1.171, 21.804), (-1.131, 23.37), (-1.09, 25.047), (-1.05, 23.894), (-1.01, 24.512), (-0.97, 27.049), (-0.93, 27.149), (-0.889, 26.742), (-0.849, 23.91), (-0.809, 24.265), (-0.769, 27.464), (-0.729, 23.775), (-0.688, 27.62), (-0.648, 28.504), (-0.608, 28.295), (-0.568, 28.096), (-0.528, 31.528), (-0.487, 31.188), (-0.447, 29.722), (-0.407, 29.521), (-0.367, 31.992), (-0.327, 28.991), (-0.286, 31.823), (-0.246, 33.04), (-0.206, 31.061), (-0.166, 32.814), (-0.126, 29.264), (-0.085, 33.214), (-0.045, 33.981), (-0.005, 36.273), (0.035, 33.327), (0.075, 34.618), (0.116, 35.065), (0.156, 31.0), (0.196, 36.441), (0.236, 38.878), (0.276, 36.338), (0.317, 37.844), (0.357, 32.963), (0.397, 35.057), (0.437, 35.193), (0.477, 39.027), (0.518, 35.477), (0.558, 36.345), (0.598, 36.056), (0.638, 39.056), (0.678, 40.193), (0.719, 36.724), (0.759, 39.845), (0.799, 43.666), (0.839, 41.484), (0.879, 39.019), (0.92, 37.805), (0.96, 45.267), (1.0, 47.807)]

xs = [x for x, y in puntos]
ys = [y for x, y in puntos]

plt.scatter(xs, ys, color='blue', label='Datos originales')
plt.title('Datos de puntos')    
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid()
plt.show()

# %%
from src import ajustar_min_cuadrados

def der_parcial_4(xs: list, ys: list) -> tuple[float, float, float, float, float, float]:
    """Derivada parcial respecto a a_4"""
    c_4 = c_3 = c_2 = c_1 = c_0 = c_ind = 0
    for x, y in zip(xs, ys):
        c_4 += x**8
        c_3 += x**7
        c_2 += x**6
        c_1 += x**5
        c_0 += x**4
        c_ind += x**4 * y
    return (c_4, c_3, c_2, c_1, c_0, c_ind)

def der_parcial_3(xs: list, ys: list) -> tuple[float, float, float, float, float, float]:
    """Derivada parcial respecto a a_3"""
    c_4 = c_3 = c_2 = c_1 = c_0 = c_ind = 0
    for x, y in zip(xs, ys):
        c_4 += x**7
        c_3 += x**6
        c_2 += x**5
        c_1 += x**4
        c_0 += x**3
        c_ind += x**3 * y
    return (c_4, c_3, c_2, c_1, c_0, c_ind)

def der_parcial_2(xs: list, ys: list) -> tuple[float, float, float, float, float, float]:
    """Derivada parcial respecto a a_2"""
    c_4 = c_3 = c_2 = c_1 = c_0 = c_ind = 0
    for x, y in zip(xs, ys):
        c_4 += x**6
        c_3 += x**5
        c_2 += x**4
        c_1 += x**3
        c_0 += x**2
        c_ind += x**2 * y
    return (c_4, c_3, c_2, c_1, c_0, c_ind)

def der_parcial_1(xs: list, ys: list) -> tuple[float, float, float, float, float, float]:
    """Derivada parcial respecto a a_1"""
    c_4 = c_3 = c_2 = c_1 = c_0 = c_ind = 0
    for x, y in zip(xs, ys):
        c_4 += x**5
        c_3 += x**4
        c_2 += x**3
        c_1 += x**2
        c_0 += x
        c_ind += x * y
    return (c_4, c_3, c_2, c_1, c_0, c_ind)

def der_parcial_0(xs: list, ys: list) -> tuple[float, float, float, float, float, float]:
    """Derivada parcial respecto a a_0"""
    c_4 = c_3 = c_2 = c_1 = c_0 = c_ind = 0
    for x, y in zip(xs, ys):
        c_4 += x**4
        c_3 += x**3
        c_2 += x**2
        c_1 += x
        c_0 += 1
        c_ind += y
    return (c_4, c_3, c_2, c_1, c_0, c_ind)


# UTILICE:
# ajustar_min_cuadrados()
a = ajustar_min_cuadrados(xs, ys, gradiente=[der_parcial_0, der_parcial_1, der_parcial_2, der_parcial_3, der_parcial_4])

def fit(x):
    """Función de ajuste"""
    return a[0] * x**4 + a[1] * x**3 + a[2] * x**2 + a[3] * x + a[4]

x_fit = np.linspace(min(xs), max(xs), 100)
y_fit = fit(x_fit)

error_rel = 0
for i in range(len(xs)):
    error_rel += abs(ys[i] - fit(xs[i]))/ys[i]

error_rel = error_rel/len(xs)

print(f'Error relativo: {error_rel}')
# Out:
# [08-07 12:50:58][INFO] Se ajustarán 5 parámetros.
# [08-07 12:50:58][INFO]
# [[ 8.48273746e+04 -1.50967503e+04  2.87741670e+03 -6.00000000e+02
#    2.00000000e+02  4.07553400e+03]
#  [ 0.00000000e+00 -3.48246747e+03  1.73496575e+03 -6.32338987e+02
#    5.69918562e+02  1.48766811e+04]
#  [ 4.65661287e-10  3.51735812e+04 -1.64526560e+04  6.02219932e+03
#   -4.16223317e+03 -9.97956366e+04]
#  [ 0.00000000e+00 -2.78209810e+05  1.25904751e+05 -4.48953073e+04
#    2.81441436e+04  6.51841142e+05]
#  [ 0.00000000e+00  2.02711567e+06 -8.96175876e+05  3.13260257e+05
#   -1.84994578e+05 -4.18976507e+06]]
# [08-07 12:50:58][INFO]
# [[ 8.48273746e+04 -1.50967503e+04  2.87741670e+03 -6.00000000e+02
#    2.00000000e+02  4.07553400e+03]
#  [ 0.00000000e+00 -3.48246747e+03  1.73496575e+03 -6.32338987e+02
#    5.69918562e+02  1.48766811e+04]
#  [ 4.65661287e-10  0.00000000e+00  1.07082673e+03 -3.64544242e+02
#    1.59405227e+03  5.04616609e+04]
#  [ 0.00000000e+00  0.00000000e+00 -1.26994121e+04  5.62143434e+03
#   -1.73859112e+04 -5.36637618e+05]
#  [ 0.00000000e+00  0.00000000e+00  1.13733412e+05 -5.48190661e+04
#    1.46750329e+05  4.46982862e+06]]
# [08-07 12:50:58][INFO]
# [[ 8.48273746e+04 -1.50967503e+04  2.87741670e+03 -6.00000000e+02
#    2.00000000e+02  4.07553400e+03]
#  [ 0.00000000e+00 -3.48246747e+03  1.73496575e+03 -6.32338987e+02
#    5.69918562e+02  1.48766811e+04]
#  [ 4.65661287e-10  0.00000000e+00  1.07082673e+03 -3.64544242e+02
#    1.59405227e+03  5.04616609e+04]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.29814150e+03
#    1.51866609e+03  6.18097369e+04]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 -1.61005139e+04
#   -2.25553107e+04 -8.89747049e+05]]
# [08-07 12:50:58][INFO]
# [[ 8.48273746e+04 -1.50967503e+04  2.87741670e+03 -6.00000000e+02
#    2.00000000e+02  4.07553400e+03]
#  [ 0.00000000e+00 -3.48246747e+03  1.73496575e+03 -6.32338987e+02
#    5.69918562e+02  1.48766811e+04]
#  [ 4.65661287e-10  0.00000000e+00  1.07082673e+03 -3.64544242e+02
#    1.59405227e+03  5.04616609e+04]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.29814150e+03
#    1.51866609e+03  6.18097369e+04]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 -1.81898940e-12
#   -3.71968722e+03 -1.23136834e+05]]
# Error relativo: 0.053141597415124725

# %%
for i in range(len(a)):
    print(f'a_{i} = {a[i]}')
# Out:
# a_0 = -0.002791214744892713
# a_1 = -0.034464964216828285
# a_2 = 0.8698657687416814
# a_3 = 8.886310723402143
# a_4 = 33.10408302045792

# %%
x = np.linspace(min(xs), max(xs), 100)
y = fit(x)

plt.plot(x, y, color ='red',label='f(x)')
plt.scatter(xs, ys, color='blue', label='Datos originales')
plt.axhline(0, color='black', lw=0.5, ls='--')
plt.axvline(0, color='black', lw=0.5, ls='--')
plt.title('Gráfico de la función f(x)')
plt.xlabel('x') 
plt.ylabel('f(x)')
plt.grid()
plt.legend()
plt.show()

# %%
# Calcular el error relativo máximo
# ####################################################################
error_rel_max = 0
for i in range(len(xs)):
    error_rel_max = abs(ys[i] - fit(xs[i]))/ys[i]
    if error_rel_max > error_rel:
        print(f'Error relativo máximo encontrado: {error_rel_max} en el punto x = {xs[i]}')

print(f'Error relativo: {error_rel_max}')
# Out:
# Error relativo máximo encontrado: 0.06940682109319034 en el punto x = -6.92
# Error relativo máximo encontrado: 0.0758197713883017 en el punto x = -6.879
# Error relativo máximo encontrado: 0.07813535381463999 en el punto x = -6.799
# Error relativo máximo encontrado: 0.06313099804633512 en el punto x = -6.759
# Error relativo máximo encontrado: 0.10116991289611593 en el punto x = -6.558
# Error relativo máximo encontrado: 0.09229174299307331 en el punto x = -6.518
# Error relativo máximo encontrado: 0.07290321854696853 en el punto x = -6.477
# Error relativo máximo encontrado: 0.09105710362843103 en el punto x = -6.317
# Error relativo máximo encontrado: 0.09776160450906701 en el punto x = -6.236
# Error relativo máximo encontrado: 0.10293416588750486 en el punto x = -6.035
# Error relativo máximo encontrado: 0.1431405072550844 en el punto x = -5.955
# Error relativo máximo encontrado: 0.10492756804770478 en el punto x = -5.834
# Error relativo máximo encontrado: 0.06326884479357256 en el punto x = -5.553
# Error relativo máximo encontrado: 0.06164664673552155 en el punto x = -5.513
# Error relativo máximo encontrado: 0.17263573714259983 en el punto x = -5.392
# Error relativo máximo encontrado: 0.09562838241231444 en el punto x = -5.352
# Error relativo máximo encontrado: 0.10119932304309849 en el punto x = -5.151
# Error relativo máximo encontrado: 0.05704629707809831 en el punto x = -5.03
# Error relativo máximo encontrado: 0.0618084332822049 en el punto x = -4.869
# Error relativo máximo encontrado: 0.13368997452978326 en el punto x = -4.588
# Error relativo máximo encontrado: 0.0678984522353124 en el punto x = -4.548
# Error relativo máximo encontrado: 0.12858627277163898 en el punto x = -4.427
# Error relativo máximo encontrado: 0.09776212340726716 en el punto x = -4.226
# Error relativo máximo encontrado: 0.12370871162452214 en el punto x = -4.186
# Error relativo máximo encontrado: 0.057708318375428995 en el punto x = -4.146
# Error relativo máximo encontrado: 0.061579861422976 en el punto x = -4.025
# Error relativo máximo encontrado: 0.05784508965854389 en el punto x = -3.945
# Error relativo máximo encontrado: 0.10240646611410249 en el punto x = -3.864
# Error relativo máximo encontrado: 0.09393847725749227 en el punto x = -3.824
# Error relativo máximo encontrado: 0.06050182733064047 en el punto x = -3.784
# Error relativo máximo encontrado: 0.0667501041760186 en el punto x = -3.744
# Error relativo máximo encontrado: 0.07108413523703824 en el punto x = -3.704
# Error relativo máximo encontrado: 0.07690873104902334 en el punto x = -3.623
# Error relativo máximo encontrado: 0.059962313271187395 en el punto x = -3.543
# Error relativo máximo encontrado: 0.08130119242248543 en el punto x = -3.503
# Error relativo máximo encontrado: 0.07232562076876736 en el punto x = -3.462
# Error relativo máximo encontrado: 0.09398163095168349 en el punto x = -3.382
# Error relativo máximo encontrado: 0.07153123860726228 en el punto x = -3.342
# Error relativo máximo encontrado: 0.07270221319013503 en el punto x = -3.141
# Error relativo máximo encontrado: 0.08828925827072671 en el punto x = -2.98
# Error relativo máximo encontrado: 0.08001042937431997 en el punto x = -2.899
# Error relativo máximo encontrado: 0.11549012750206876 en el punto x = -2.859
# Error relativo máximo encontrado: 0.09975241408841869 en el punto x = -2.779
# Error relativo máximo encontrado: 0.05333941052314366 en el punto x = -2.739
# Error relativo máximo encontrado: 0.11522150211679436 en el punto x = -2.698
# Error relativo máximo encontrado: 0.05791335272608992 en el punto x = -2.538
# Error relativo máximo encontrado: 0.08931079808520619 en el punto x = -2.417
# Error relativo máximo encontrado: 0.06894939194647558 en el punto x = -2.377
# Error relativo máximo encontrado: 0.11301979948709494 en el punto x = -2.256
# Error relativo máximo encontrado: 0.06408268146481752 en el punto x = -2.176
# Error relativo máximo encontrado: 0.24293872297945743 en el punto x = -2.095
# Error relativo máximo encontrado: 0.06713566919240467 en el punto x = -2.055
# Error relativo máximo encontrado: 0.1518856177728047 en el punto x = -1.975
# Error relativo máximo encontrado: 0.159094308702974 en el punto x = -1.814
# Error relativo máximo encontrado: 0.1136090629493561 en el punto x = -1.774
# Error relativo máximo encontrado: 0.07175300498118332 en el punto x = -1.693
# Error relativo máximo encontrado: 0.13196167174049722 en el punto x = -1.653
# Error relativo máximo encontrado: 0.10900048514448203 en el punto x = -1.533
# Error relativo máximo encontrado: 0.10927768397110008 en el punto x = -1.492
# Error relativo máximo encontrado: 0.07749194736028531 en el punto x = -1.452
# Error relativo máximo encontrado: 0.07362320024242262 en el punto x = -1.372
# Error relativo máximo encontrado: 0.15171963198832913 en el punto x = -1.332
# Error relativo máximo encontrado: 0.09007024549022288 en el punto x = -1.211
# Error relativo máximo encontrado: 0.09801420090927535 en el punto x = -1.171
# Error relativo máximo encontrado: 0.06348469368521073 en el punto x = -0.97
# Error relativo máximo encontrado: 0.05640004742344459 en el punto x = -0.93
# Error relativo máximo encontrado: 0.09603706927820381 en el punto x = -0.849
# Error relativo máximo encontrado: 0.09216653619836469 en el punto x = -0.809
# Error relativo máximo encontrado: 0.13988681173111425 en el punto x = -0.729
# Error relativo máximo encontrado: 0.09098351134022808 en el punto x = -0.528
# Error relativo máximo encontrado: 0.07058552528123346 en el punto x = -0.487
# Error relativo máximo encontrado: 0.06346519965492964 en el punto x = -0.367
# Error relativo máximo encontrado: 0.06261518658806214 en el punto x = -0.246
# Error relativo máximo encontrado: 0.09343514549011427 en el punto x = -0.126
# Error relativo máximo encontrado: 0.08858729033188589 en el punto x = -0.005
# Error relativo máximo encontrado: 0.11327045323366586 en el punto x = 0.156
# Error relativo máximo encontrado: 0.0933371387352268 en el punto x = 0.236
# Error relativo máximo encontrado: 0.10383599797274208 en el punto x = 0.357
# Error relativo máximo encontrado: 0.055622998580679435 en el punto x = 0.437
# Error relativo máximo encontrado: 0.06930142142687941 en el punto x = 0.518
# Error relativo máximo encontrado: 0.05453929582397083 en el punto x = 0.558
# Error relativo máximo encontrado: 0.07392492604068522 en el punto x = 0.598
# Error relativo máximo encontrado: 0.087285445658244 en el punto x = 0.719
# Error relativo máximo encontrado: 0.06698916966068616 en el punto x = 0.799
# Error relativo máximo encontrado: 0.06517775675337736 en el punto x = 0.879
# Error relativo máximo encontrado: 0.11061780748582707 en el punto x = 0.92
# Error relativo máximo encontrado: 0.06325255695819969 en el punto x = 0.96
# Error relativo máximo encontrado: 0.1042524455908126 en el punto x = 1.0
# Error relativo: 0.1042524455908126
